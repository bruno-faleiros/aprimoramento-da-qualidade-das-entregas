# %% [markdown]
# # **Aprimoramento da Qualidade das Entregas com Python e Power BI**
# #### Bruno Faleiros - Estudante de Análise e Desenvolvimento de Sistemas
# #### Email - brunofaleiros97@gmail.com
# #### Linkedin - https://www.linkedin.com/in/brunofaleiros/

# %% [markdown]
# # **Objetivo**
#
# O projeto se concentra na análise e limpeza desses dados, com o uso da linguagem de programação Python, destacando a
# biblioteca Pandas para manipulação e análise dos dados, e o Power BI para a visualização dos resultados. O foco principal do projeto é identificar a melhor rota de entrega nas regiões da Vila Ema, Vila Prudente e Vila Santa Clara, localizadas na zona leste de São Paulo.
#
# API utilizada: https://viacep.com.br/

# %% [markdown]
# # **Pacotes utilizados neste Notebook**
#
# 1. **Pandas:** biblioteca para manipulação de dados tabulares
# 2. **Requests:** biblioteca para fazer requisições HTTP

# %% [markdown]
# # **Verificando a versão Python**

# %%
from platform import python_version
print(f"Versão da Linguagem Python:{python_version()}")
# Out:
# Versão da Linguagem Python:3.11.5

# %%
# Importando o pacote requests 
import requests

# %%
# Importando a biblioteca requests, que será utilizada para fazer a requisição HTTP
import requests

# Escolhendo a região
uf = "SP" 
cidade = "São Paulo"
endereco = "Vila Ema"

# Construindo o URL da API do ViaCEP com base nas informações de UF, cidade e endereço
link = f"https://viacep.com.br/ws/{uf}/{cidade}/{endereco}/json/"

# Realizando uma requisição HTTP GET para o URL da API do ViaCEP
requisicao = requests.get(link)

# Imprimindo a resposta da requisição HTTP (status code e outras informações)
print(requisicao)

# Convertendo a resposta da requisição para formato JSON 
requisicao_json = requisicao.json()

# Imprimindo as informações obtidas da API no formato JSON
print(requisicao_json)
# Out:
# <Response [200]>
# [{'cep': '03281-000', 'logradouro': 'Avenida Vila Ema', 'complemento': 'de 1387 a 3701 - lado ímpar', 'bairro': 'Vila Ema', 'localidade': 'São Paulo', 'uf': 'SP', 'ibge': '3550308', 'gia': '1004', 'ddd': '11', 'siafi': '7107'}, {'cep': '03281-904', 'logradouro': 'Avenida Vila Ema', 'complemento': '3883', 'bairro': 'Vila Ema', 'localidade': 'São Paulo', 'uf': 'SP', 'ibge': '3550308', 'gia': '1004', 'ddd': '11', 'siafi': '7107'}, {'cep': '03275-905', 'logradouro': 'Avenida Vila Ema', 'complemento': '2718', 'bairro': 'Vila Ema', 'localidade': 'São Paulo', 'uf': 'SP', 'ibge': '3550308', 'gia': '1004', 'ddd': '11', 'siafi': '7107'}, {'cep': '03156-000', 'logradouro': 'Avenida Vila Ema', 'complemento': 'até 1384 - lado par', 'bairro': 'Vila Prudente', 'localidade': 'São Paulo', 'uf': 'SP', 'ibge': '3550308', 'gia': '1004', 'ddd': '11', 'siafi': '7107'}, {'cep': '03281-001', 'logradouro': 'Avenida Vila Ema', 'complemento': 'de 3703 ao fim - lado ímpar', 'bairro': 'Vila Ema', 'localidade': 'São Paulo', 'uf': 'SP', 'ibge': '3550308', 'gia': '1004', 'ddd': '11', 'siafi': '7107'}, {'cep': '03282-907', 'logradouro': 'Avenida Vila Ema', 'complemento': '3054', 'bairro': 'Vila Ema', 'localidade': 'São Paulo', 'uf': 'SP', 'ibge': '3550308', 'gia': '1004', 'ddd': '11', 'siafi': '7107'}, {'cep': '03257-906', 'logradouro': 'Avenida Vila Ema', 'complemento': '119', 'bairro': 'Vila Ema', 'localidade': 'São Paulo', 'uf': 'SP', 'ibge': '3550308', 'gia': '1004', 'ddd': '11', 'siafi': '7107'}, {'cep': '03156-001', 'logradouro': 'Avenida Vila Ema', 'complemento': 'até 1385 - lado ímpar', 'bairro': 'Vila Prudente', 'localidade': 'São Paulo', 'uf': 'SP', 'ibge': '3550308', 'gia': '1004', 'ddd': '11', 'siafi': '7107'}, {'cep': '03282-000', 'logradouro': 'Avenida Vila Ema', 'complemento': 'de 1386 a 3700 - lado par', 'bairro': 'Vila Ema', 'localidade': 'São Paulo', 'uf': 'SP', 'ibge': '3550308', 'gia': '1004', 'ddd': '11', 'siafi': '7107'}, {'cep': '03281-903', 'logradouro': 'Avenida Vila Ema', 'complemento': '3881', 'bairro': 'Vila Ema', 'localidade': 'São Paulo', 'uf': 'SP', 'ibge': '3550308', 'gia': '1004', 'ddd': '11', 'siafi': '7107'}, {'cep': '03294-908', 'logradouro': 'Avenida Vila Ema', 'complemento': '4822', 'bairro': 'Vila Ema', 'localidade': 'São Paulo', 'uf': 'SP', 'ibge': '3550308', 'gia': '1004', 'ddd': '11', 'siafi': '7107'}, {'cep': '03156-900', 'logradouro': 'Avenida Vila Ema', 'complemento': '1006', 'bairro': 'Vila Santa Clara', 'localidade': 'São Paulo', 'uf': 'SP', 'ibge': '3550308', 'gia': '1004', 'ddd': '11', 'siafi': '7107'}, {'cep': '03282-001', 'logradouro': 'Avenida Vila Ema', 'complemento': 'de 3702 ao fim - lado par', 'bairro': 'Vila Ema', 'localidade': 'São Paulo', 'uf': 'SP', 'ibge': '3550308', 'gia': '1004', 'ddd': '11', 'siafi': '7107'}, {'cep': '03281-902', 'logradouro': 'Avenida Vila Ema', 'complemento': '3793', 'bairro': 'Vila Ema', 'localidade': 'São Paulo', 'uf': 'SP', 'ibge': '3550308', 'gia': '1004', 'ddd': '11', 'siafi': '7107'}, {'cep': '03295-909', 'logradouro': 'Avenida Vila Ema', 'complemento': '5001', 'bairro': 'Vila Ema', 'localidade': 'São Paulo', 'uf': 'SP', 'ibge': '3550308', 'gia': '1004', 'ddd': '11', 'siafi': '7107'}, {'cep': '03156-901', 'logradouro': 'Avenida Vila Ema', 'complemento': '1200', 'bairro': 'Vila Santa Clara', 'localidade': 'São Paulo', 'uf': 'SP', 'ibge': '3550308', 'gia': '1004', 'ddd': '11', 'siafi': '7107'}]

# %%
# Importando o pacote pandas
import pandas as pd

# Convertendo o arquivo JSON para o formato Pandas DataFrame
df = pd.DataFrame(requisicao_json)

# Exibindo as primeiras linhas do DataFrame
df.head()
# Out:
#          cep        logradouro                  complemento         bairro  \
# 0  03281-000  Avenida Vila Ema  de 1387 a 3701 - lado ímpar       Vila Ema
# 1  03281-904  Avenida Vila Ema                         3883       Vila Ema
# 2  03275-905  Avenida Vila Ema                         2718       Vila Ema
# 3  03156-000  Avenida Vila Ema          até 1384 - lado par  Vila Prudente
# 4  03281-001  Avenida Vila Ema  de 3703 ao fim - lado ímpar       Vila Ema
#
#   localidade  uf     ibge   gia ddd siafi
# 0  São Paulo  SP  3550308  1004  11  7107
# 1  São Paulo  SP  3550308  1004  11  7107
# 2  São Paulo  SP  3550308  1004  11  7107
# 3  São Paulo  SP  3550308  1004  11  7107
# 4  São Paulo  SP  3550308  1004  11  7107

# %%
display(df)
# Out:
#           cep        logradouro                  complemento  \
# 0   03281-000  Avenida Vila Ema  de 1387 a 3701 - lado ímpar
# 1   03281-904  Avenida Vila Ema                         3883
# 2   03275-905  Avenida Vila Ema                         2718
# 3   03156-000  Avenida Vila Ema          até 1384 - lado par
# 4   03281-001  Avenida Vila Ema  de 3703 ao fim - lado ímpar
# 5   03282-907  Avenida Vila Ema                         3054
# 6   03257-906  Avenida Vila Ema                          119
# 7   03156-001  Avenida Vila Ema        até 1385 - lado ímpar
# 8   03282-000  Avenida Vila Ema    de 1386 a 3700 - lado par
# 9   03281-903  Avenida Vila Ema                         3881
# 10  03294-908  Avenida Vila Ema                         4822
# 11  03156-900  Avenida Vila Ema                         1006
# 12  03282-001  Avenida Vila Ema    de 3702 ao fim - lado par
# 13  03281-902  Avenida Vila Ema                         3793
# 14  03295-909  Avenida Vila Ema                         5001
# 15  03156-901  Avenida Vila Ema                         1200
#
#               bairro localidade  uf     ibge   gia ddd siafi
# 0           Vila Ema  São Paulo  SP  3550308  1004  11  7107
# 1           Vila Ema  São Paulo  SP  3550308  1004  11  7107
# 2           Vila Ema  São Paulo  SP  3550308  1004  11  7107
# 3      Vila Prudente  São Paulo  SP  3550308  1004  11  7107
# 4           Vila Ema  São Paulo  SP  3550308  1004  11  7107
# 5           Vila Ema  São Paulo  SP  3550308  1004  11  7107
# 6           Vila Ema  São Paulo  SP  3550308  1004  11  7107
# 7      Vila Prudente  São Paulo  SP  3550308  1004  11  7107
# 8           Vila Ema  São Paulo  SP  3550308  1004  11  7107
# 9           Vila Ema  São Paulo  SP  3550308  1004  11  7107
# 10          Vila Ema  São Paulo  SP  3550308  1004  11  7107
# 11  Vila Santa Clara  São Paulo  SP  3550308  1004  11  7107
# 12          Vila Ema  São Paulo  SP  3550308  1004  11  7107
# 13          Vila Ema  São Paulo  SP  3550308  1004  11  7107
# 14          Vila Ema  São Paulo  SP  3550308  1004  11  7107
# 15  Vila Santa Clara  São Paulo  SP  3550308  1004  11  7107

# %% [markdown]
# ### Insight
#
# - Os números das colunas ibge, gia, ddd e siafi se repetem. Para simplificar essa análise, optarei por excluí-los

# %%
# Remove as colunas 'ibge', 'gia', 'ddd' e 'siafi' do DataFrame 
df = df.drop(columns=['ibge', 'gia', 'ddd', 'siafi'])

# Exibindo as primeiras linhas do DataFrame
df.head()
# Out:
#          cep        logradouro                  complemento         bairro  \
# 0  03281-000  Avenida Vila Ema  de 1387 a 3701 - lado ímpar       Vila Ema
# 1  03281-904  Avenida Vila Ema                         3883       Vila Ema
# 2  03275-905  Avenida Vila Ema                         2718       Vila Ema
# 3  03156-000  Avenida Vila Ema          até 1384 - lado par  Vila Prudente
# 4  03281-001  Avenida Vila Ema  de 3703 ao fim - lado ímpar       Vila Ema
#
#   localidade  uf
# 0  São Paulo  SP
# 1  São Paulo  SP
# 2  São Paulo  SP
# 3  São Paulo  SP
# 4  São Paulo  SP

# %%
# Informações do conjunto de dados
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cep          16 non-null     object
#  1   logradouro   16 non-null     object
#  2   complemento  16 non-null     object
#  3   bairro       16 non-null     object
#  4   localidade   16 non-null     object
#  5   uf           16 non-null     object
# dtypes: object(6)
# memory usage: 900.0+ bytes

# %% [markdown]
# ## Tratando os dados

# %%
# Removendo o caractere '-' da coluna 'cep'
df['cep'] = df['cep'].str.replace('-', '')

# Exibindo as primeiras linhas do DataFrame
df.head()
# Out:
#         cep        logradouro                  complemento         bairro  \
# 0  03281000  Avenida Vila Ema  de 1387 a 3701 - lado ímpar       Vila Ema
# 1  03281904  Avenida Vila Ema                         3883       Vila Ema
# 2  03275905  Avenida Vila Ema                         2718       Vila Ema
# 3  03156000  Avenida Vila Ema          até 1384 - lado par  Vila Prudente
# 4  03281001  Avenida Vila Ema  de 3703 ao fim - lado ímpar       Vila Ema
#
#   localidade  uf
# 0  São Paulo  SP
# 1  São Paulo  SP
# 2  São Paulo  SP
# 3  São Paulo  SP
# 4  São Paulo  SP

# %%
# Substituição do texto 'Avenida' por 'Av. ' na coluna 'logradouro'
df['logradouro'] = df['logradouro'].str.replace('Avenida', 'Av. ').str.upper()

# Exibindo as primeiras linhas do DataFrame
df.head()
# Out:
#         cep     logradouro                  complemento         bairro  \
# 0  03281000  AV.  VILA EMA  de 1387 a 3701 - lado ímpar       Vila Ema
# 1  03281904  AV.  VILA EMA                         3883       Vila Ema
# 2  03275905  AV.  VILA EMA                         2718       Vila Ema
# 3  03156000  AV.  VILA EMA          até 1384 - lado par  Vila Prudente
# 4  03281001  AV.  VILA EMA  de 3703 ao fim - lado ímpar       Vila Ema
#
#   localidade  uf
# 0  São Paulo  SP
# 1  São Paulo  SP
# 2  São Paulo  SP
# 3  São Paulo  SP
# 4  São Paulo  SP

# %%
# Mantendo apenas os números na coluna 'complemento'
df['complemento'] = df['complemento'].str.extract(r'(\d+)', expand=False)

# Exibindo as primeiras linhas do DataFrame
df.head()
# Out:
#         cep     logradouro complemento         bairro localidade  uf
# 0  03281000  AV.  VILA EMA        1387       Vila Ema  São Paulo  SP
# 1  03281904  AV.  VILA EMA        3883       Vila Ema  São Paulo  SP
# 2  03275905  AV.  VILA EMA        2718       Vila Ema  São Paulo  SP
# 3  03156000  AV.  VILA EMA        1384  Vila Prudente  São Paulo  SP
# 4  03281001  AV.  VILA EMA        3703       Vila Ema  São Paulo  SP

# %%
# Converter todos os valores da coluna 'bairro' para maiúsculas e atribuir à mesma coluna
df['bairro'] = df['bairro'].str.upper()

# Exibindo as primeiras linhas do DataFrame
df.head()
# Out:
#         cep     logradouro complemento         bairro localidade  uf
# 0  03281000  AV.  VILA EMA        1387       VILA EMA  São Paulo  SP
# 1  03281904  AV.  VILA EMA        3883       VILA EMA  São Paulo  SP
# 2  03275905  AV.  VILA EMA        2718       VILA EMA  São Paulo  SP
# 3  03156000  AV.  VILA EMA        1384  VILA PRUDENTE  São Paulo  SP
# 4  03281001  AV.  VILA EMA        3703       VILA EMA  São Paulo  SP

# %%
# Mapeando os valores originais para os valores codificados
label_encoding = {
    'VILA EMA': 1,
    'VILA PRUDENTE': 0,
    'VILA SANTA CLARA': 2
}

# Aplicando o label encoding à coluna 'bairro'
df['codigo_bairro'] = df['bairro'].map(label_encoding)

# Exibindo as primeiras linhas do DataFrame
df.head()
# Out:
#         cep     logradouro complemento         bairro localidade  uf  \
# 0  03281000  AV.  VILA EMA        1387       VILA EMA  São Paulo  SP
# 1  03281904  AV.  VILA EMA        3883       VILA EMA  São Paulo  SP
# 2  03275905  AV.  VILA EMA        2718       VILA EMA  São Paulo  SP
# 3  03156000  AV.  VILA EMA        1384  VILA PRUDENTE  São Paulo  SP
# 4  03281001  AV.  VILA EMA        3703       VILA EMA  São Paulo  SP
#
#    codigo_bairro
# 0              1
# 1              1
# 2              1
# 3              0
# 4              1

# %%
# Definindo a nova ordem das colunas no DataFrame
nova_ordem_colunas = ["cep", "logradouro", "complemento", "bairro", "codigo_bairro", 
                      "localidade", "uf"]

# Reorganiza as colunas do DataFrame df de acordo com a ordem especificada em nova_ordem_colunas
df = df[nova_ordem_colunas]

# Exibindo as primeiras linhas do DataFrame
df.head()
# Out:
#         cep     logradouro complemento         bairro  codigo_bairro  \
# 0  03281000  AV.  VILA EMA        1387       VILA EMA              1
# 1  03281904  AV.  VILA EMA        3883       VILA EMA              1
# 2  03275905  AV.  VILA EMA        2718       VILA EMA              1
# 3  03156000  AV.  VILA EMA        1384  VILA PRUDENTE              0
# 4  03281001  AV.  VILA EMA        3703       VILA EMA              1
#
#   localidade  uf
# 0  São Paulo  SP
# 1  São Paulo  SP
# 2  São Paulo  SP
# 3  São Paulo  SP
# 4  São Paulo  SP

# %%
# Substituindo 'São Paulo' por 'SAO PAULO' na coluna 'localidade'
df['localidade'] = df['localidade'].str.replace('São Paulo', 'SAO PAULO')

# Exibindo as primeiras linhas do DataFrame
df.head()
# Out:
#         cep     logradouro complemento         bairro  codigo_bairro  \
# 0  03281000  AV.  VILA EMA        1387       VILA EMA              1
# 1  03281904  AV.  VILA EMA        3883       VILA EMA              1
# 2  03275905  AV.  VILA EMA        2718       VILA EMA              1
# 3  03156000  AV.  VILA EMA        1384  VILA PRUDENTE              0
# 4  03281001  AV.  VILA EMA        3703       VILA EMA              1
#
#   localidade  uf
# 0  SAO PAULO  SP
# 1  SAO PAULO  SP
# 2  SAO PAULO  SP
# 3  SAO PAULO  SP
# 4  SAO PAULO  SP

# %%
# Adiciona uma nova coluna chamada 'paridade' ao DataFrame df, onde o valor de cada célula é determinado pela aplicação de uma função lambda à coluna 'complemento'
# A função lambda verifica se o valor numérico em 'complemento' é par ou ímpar e atribui 'PAR' ou 'IMPAR' à célula correspondente na coluna 'paridade'
df['paridade'] = df['complemento'].apply(lambda num: 'PAR' if int(num) % 2 == 0 else 'IMPAR')

# Exibindo as primeiras linhas do DataFrame
df.head()
# Out:
#         cep     logradouro complemento         bairro  codigo_bairro  \
# 0  03281000  AV.  VILA EMA        1387       VILA EMA              1
# 1  03281904  AV.  VILA EMA        3883       VILA EMA              1
# 2  03275905  AV.  VILA EMA        2718       VILA EMA              1
# 3  03156000  AV.  VILA EMA        1384  VILA PRUDENTE              0
# 4  03281001  AV.  VILA EMA        3703       VILA EMA              1
#
#   localidade  uf paridade
# 0  SAO PAULO  SP    IMPAR
# 1  SAO PAULO  SP    IMPAR
# 2  SAO PAULO  SP      PAR
# 3  SAO PAULO  SP      PAR
# 4  SAO PAULO  SP    IMPAR

# %%
# Definindo a nova ordem das colunas no DataFrame
nova_ordem_colunas = ["cep", "logradouro", "complemento", "paridade", "bairro", "codigo_bairro", 
                      "localidade", "uf"]

df = df[nova_ordem_colunas]

# Exibindo as primeiras linhas do DataFrame
df.head()
# Out:
#         cep     logradouro complemento paridade         bairro  codigo_bairro  \
# 0  03281000  AV.  VILA EMA        1387    IMPAR       VILA EMA              1
# 1  03281904  AV.  VILA EMA        3883    IMPAR       VILA EMA              1
# 2  03275905  AV.  VILA EMA        2718      PAR       VILA EMA              1
# 3  03156000  AV.  VILA EMA        1384      PAR  VILA PRUDENTE              0
# 4  03281001  AV.  VILA EMA        3703    IMPAR       VILA EMA              1
#
#   localidade  uf
# 0  SAO PAULO  SP
# 1  SAO PAULO  SP
# 2  SAO PAULO  SP
# 3  SAO PAULO  SP
# 4  SAO PAULO  SP

# %%
# Informações do conjunto de dados
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cep            16 non-null     object
#  1   logradouro     16 non-null     object
#  2   complemento    16 non-null     object
#  3   paridade       16 non-null     object
#  4   bairro         16 non-null     object
#  5   codigo_bairro  16 non-null     int64
#  6   localidade     16 non-null     object
#  7   uf             16 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 1.1+ KB

# %%
# Salva o DataFrame df em um arquivo do Excel chamado 'projeto-linktou1.xlsx', sem incluir o índice das linhas no arquivo
df.to_excel('dados_entregas_linktou.xlsx', index=False)

# %% [markdown]
# # **Visualização dos Dados no Power BI**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - **Identificação da Melhor Rota de Entrega**: A análise dos dados permitiu identificar a melhor rota de entrega nas regiões especificadas, levando em consideração fatores como distância, tempo e condições das vias.
#
# - **Otimização das Entregas**: Com base na análise realizada, foi possível otimizar as rotas de entrega, reduzindo custos e tempo de transporte.
#
# - **Melhoria na Qualidade das Entregas**: A implementação da melhor rota contribuiu para a melhoria da qualidade das entregas, garantindo maior eficiência e satisfação do cliente.
